# %% [markdown]
# # Introduction
# This notebook is used to validate the dataset. It is used to check if the dataset created in the fastf1_test.ipynb file is acceptable.

# %%
# imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = os.path.join('data', '2022', 'bahrain_grand_prix.csv')
df = pd.read_csv(
    path, #Time delta is not supported by pandas...
    dtype={
    'LapStartTime': pd.Timedelta,
    'LapNumber': np.uint8,
    'LapTime': pd.Timedelta,
    'Compound': "category",
    'TyreLife': np.uint8,
    'TrackStatus': "category",
    'Stint': np.uint8,
    'DistanceToDriverAhead': np.float32,
    'DriverAhead': "category",
    'Track': "category",
    'Time': pd.Timedelta,
    'AirTemp': np.float32,
    'Humidity': np.float32,
    'Pressure': np.float32,
    'Rainfall': np.bool8,
    'TrackTemp': np.float32,
    'WindDirection': np.int32,
    'WindSpeed': np.float32
    },
)
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 path = os.path.join('data', '2022', 'bahrain_grand_prix.csv')
# ----> 2 df = pd.read_csv(
#       3     path,
#       4     dtype={
#       5     'LapStartTime': pd.Timedelta,
#       6
#       7     },
#       8 )
#       9 df.info()
#
# File p:\Anaconda\envs\bsc\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File p:\Anaconda\envs\bsc\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
# Out:
# <AxesSubplot: >
